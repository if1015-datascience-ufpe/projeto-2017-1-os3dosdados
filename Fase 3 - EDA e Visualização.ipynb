# %% [markdown]
# # Fase 3 - EDA e Visualização

# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
% matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1a41a41f-dafe-486d-81f4-9ec5cd9e1cc3">Loading BokehJS ...</span>
#     </div>

# %%
dtf = pd.read_csv('saidaPreProcessamento/saidaPreProcessamentoAval.csv',na_values=0,sep=';',index_col=False, header=0)
dtf = dtf.iloc[:,1:]
dtf['Nome'] = dtf.Nome.astype('category')

#Calculando a média e ordenando por ela
dtf['Nota'] = dtf.mean(numeric_only=True, axis=1)
dtf.sort_values(by='Nota',inplace=True,ascending=False)
dtf.reset_index(inplace=True,drop=True)
dtf.head()
# Out:
#                                               Nome  Localização  Quartos  \
# 0                      Courtyard Recife Boa Viagem          8.5     8.50
# 1  Transamérica Prestige Beach Class International          8.9     8.40
# 2                Bristol Recife Hotel & Convention          8.4     7.55
# 3               Bristol Recife Suites & Convention          8.2     8.50
# 4                     Nobile Beach Class Executive          8.8     8.30
#
#    Serviço  Limpeza  Custo-Benefício  Conforto  Facilidades  Prédio     Nota
# 0      8.7      9.0              8.2       8.9          8.5     8.8  8.63750
# 1      8.8      8.8              7.9       8.9          8.5     8.5  8.58750
# 2      8.4      8.9              8.3       8.8          8.5     8.6  8.43125
# 3      8.2      8.8              8.2       8.7          8.2     8.5  8.41250
# 4      8.4      8.7              7.9       8.6          8.4     8.1  8.40000

# %%
#hoteis= ['Radisson Recife', 'Golden Tulip', 'Marhotel', 'Atlante Plaza' ]
avaliacoes.mean(axis=1).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ea5797e41be5> in <module>()
#       1 #hoteis= ['Radisson Recife', 'Golden Tulip', 'Marhotel', 'Atlante Plaza' ]
# ----> 2 avaliacoes.mean(axis=1).plot.bar()
#
# NameError: name 'avaliacoes' is not defined
