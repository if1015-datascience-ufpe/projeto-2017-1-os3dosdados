# %% [markdown]
# # Uma análise quantitativa dos hotéis em Recife a partir dos dados do Trivago
#
# Ângelo de Sant'Ana &mdash;
# assd {em} cin.ufpe.br;
#
# Antônio Rodrigues &mdash;
# acpr {em} cin.ufpe.br;
#
# Juliana Carvalho &mdash;
# jco2 {em} cin.ufpe.br
#
# junho de 2017

# %%
from bs4 import BeautifulSoup

# %%
url = "../pages/avaliacoesPag1.html"
parsed_page = BeautifulSoup(open(url,encoding="latin1"),"html.parser")
parsed_page.title.text
# allDivs = parsed_page.find_all('div', class_="rat-chart__group rat-chart__group--collapsed")
# print(allDivs)
# Out:
# [<div class="rat-chart__group rat-chart__group--collapsed"><div class="rat-chart__item"><span class="rat-chart__label">LocalizaÃ§Ã£o</span><span class="rat-chart__bar"><span class="rat-chart__bar-holder"><span class="rat-chart__bar-content rat-color--5" style="width: 92%;"></span></span></span><span class="rat-chart__number"><span class="rat-chart__score-string v-tablet-wider-inline-block">Excelente
# ...
