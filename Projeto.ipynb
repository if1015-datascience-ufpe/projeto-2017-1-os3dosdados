# %% [markdown]
# # Uma análise quantitativa dos hotéis em Recife a partir dos dados do Trivago
#
# Ângelo de Sant'Ana &mdash;
# assd {em} cin.ufpe.br;
#
# Antônio Rodrigues &mdash;
# acpr {em} cin.ufpe.br;
#
# Juliana Carvalho &mdash;
# jco2 {em} cin.ufpe.br
#
# junho de 2017

# %%
from bs4 import BeautifulSoup

# %%
# fazer um iterador para capturar todas as páginas de 1 a 5

urlAvaliacoes = "pages/avaliacoesPag1.html"

parsed_page_avaliacoes = BeautifulSoup(open(urlAvaliacoes,encoding="latin1"),"html.parser")

# allDivs = parsed_page_avaliacoes.find_all('div', class_="rat-chart__group rat-chart__group--collapsed")

# print(allDivs)

# para os conjuntos das avaliações
# class_="rat-chart__group rat-chart__group--collapsed"

# para o item de avaliação exibido
# class_="rat-chart__item"

# para o nome da característica (coluna)
# class_="rat-chart__label"

# para o valor da avaliação
# class_="parentesis-wrapper"

urlInfos = "pages/InfoPag1.html"

parsed_page_infos = BeautifulSoup(open(urlInfos,encoding="latin1"),"html.parser")

# para todas as comodidades do hotel
# class_="sl-box__block clearfix"

allDivs = parsed_page_infos.find_all('div', class_="sl-box__block clearfix")

# print(allDivs)

# para cada uma das comodidades do hotel
# class_="all-amenities__group mb-gutter"

# sobre os quartos
# class_="sl-box__content"
# Out:
# [<div class="sl-box__block clearfix"><div class="all-amenities__group mb-gutter"><h5 class="block mt-0 mb-gutter-three-quarters font-small fw-normal">Comodidades do Hotel</h5><ul class="unordered-list m-0" itemscope="true" itemtype="https://schema.org/Accommodation"><li class="unordered-list__item" itemprop="amenityFeature">Academia</li><li class="unordered-list__item" itemprop="amenityFeature">Bar no hotel</li><li class="unordered-list__item" itemprop="amenityFeature">Cadeira de sol</li><li class="unordered-list__item" itemprop="amenityFeature">Elevador</li><li class="unordered-list__item" itemprop="amenityFeature">Estacionamento</li><li class="unordered-list__item" itemprop="amenityFeature">Guarda-sol</li><li class="unordered-list__item" itemprop="amenityFeature">Lavanderia</li><li class="unordered-list__item" itemprop="amenityFeature">Piscina exterior</li><li class="unordered-list__item" itemprop="amenityFeature">Quarto para nÃ£o-fumantes</li><li class="unordered-list__item" itemprop="amenityFeature">RecepÃ§Ã£o 24 horas</li><li class="unordered-list__item" itemprop="amenityFeature">Restaurante</li><li class="unordered-list__item" itemprop="amenityFeature">Sala de conferÃªncias</li><li class="unordered-list__item" itemprop="amenityFeature">ServiÃ§o de quarto</li><li class="unordered-list__item" itemprop="amenityFeature">ServiÃ§o de quarto 24 horas</li><li class="unordered-list__item" itemprop="amenityFeature">TerraÃ§o</li><li class="unordered-list__item" itemprop="amenityFeature">Toalhas na piscina</li><li class="unordered-list__item" itemprop="amenityFeature">Wi-Fi grÃ¡tis no lobby</li><li class="unordered-list__item" itemprop="amenityFeature">Wi-Fi no Lobby</li></ul></div><div class="all-amenities__group mb-gutter"><h5 class="block mt-0 mb-gutter-three-quarters font-small fw-normal">Comodidades do Quarto</h5><ul class="unordered-list m-0" itemscope="true" itemtype="https://schema.org/Accommodation"><li class="unordered-list__item" itemprop="amenityFeature">Acesso Wi-Fi nos quartos</li><li class="unordered-list__item" itemprop="amenityFeature">Aquecedor</li><li class="unordered-list__item" itemprop="amenityFeature">Ar condicionado</li><li class="unordered-list__item" itemprop="amenityFeature">Cofre no quarto</li><li class="unordered-list__item" itemprop="amenityFeature">Ferro e tÃ¡bua de passar</li><li class="unordered-list__item" itemprop="amenityFeature">Internet</li><li class="unordered-list__item" itemprop="amenityFeature">Mesa de trabalho</li><li class="unordered-list__item" itemprop="amenityFeature">Secador</li><li class="unordered-list__item" itemprop="amenityFeature">Telefone</li><li class="unordered-list__item" itemprop="amenityFeature">TV a cabo</li><li class="unordered-list__item" itemprop="amenityFeature">TV LCD</li><li class="unordered-list__item" itemprop="amenityFeature">Wi-Fi grÃ¡tis nos quartos</li></ul></div><div class="all-amenities__group mb-gutter"><h5 class="block mt-0 mb-gutter-three-quarters font-small fw-normal">Wellness / Spa</h5><ul class="unordered-list m-0" itemscope="true" itemtype="https://schema.org/Accommodation"><li class="unordered-list__item" itemprop="amenityFeature">Massagens</li><li class="unordered-list__item" itemprop="amenityFeature">Sauna</li></ul></div><div class="all-amenities__group mb-gutter"><h5 class="block mt-0 mb-gutter-three-quarters font-small fw-normal">Acessibilidade</h5><ul class="unordered-list m-0" itemscope="true" itemtype="https://schema.org/Accommodation"><li class="unordered-list__item" itemprop="amenityFeature">AcessÃ­vel para cadeirante</li><li class="unordered-list__item" itemprop="amenityFeature">Banheiros com acessibilidade</li><li class="unordered-list__item" itemprop="amenityFeature">Corredores com acessibilidade</li><li class="unordered-list__item" itemprop="amenityFeature">Estacionamento acessÃ­vel</li></ul></div><div class="all-amenities__group mb-gutter"><h5 class="block mt-0 mb-gutter-three-quarters font-small fw-normal">Para CrianÃ§as</h5><ul class=" ...
