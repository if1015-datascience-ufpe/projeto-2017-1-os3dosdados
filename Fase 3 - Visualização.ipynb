# %% [markdown]
# # Fase 3 - Visualização

# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
% matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7b66ae7f-18fa-4a5b-9abe-9779c0b7ee2b">Loading BokehJS ...</span>
#     </div>

# %%
avaliacoes = pd.read_csv("saidaDataScraping.csv",sep=';')
avaliacoes.drop(['nome_do_hotel', 'localizacao', 'quartos', 'servico', 'limpeza', 'custo-beneficio', 
                 'conforto', 'facilidades', 'predio', 'cafe_da_manha', 'comida'],axis=1).dropna(axis=1,how='all')
avaliacoes
# Out:
#      nome_do_hotel                 localizacao  quartos  servico  limpeza  \
# 0  Radisson Recife                          87       92       83       78
# 1     Golden Tulip                          80       90       56       78
# 2         Marhotel                          87       92       83       78
# 3    Atlante Plaza  Não avaliadoNão disponível       90       56       78
#
#    custo-beneficio  conforto  facilidades  predio  cafe_da_manha  comida
# 0               67        65           88      79             70      90
# 1               90        55           89      90             78      67
# 2               67        65           88      79             70      90
# 3               90        55           89      90             78      67

# %%
#hoteis= ['Radisson Recife', 'Golden Tulip', 'Marhotel', 'Atlante Plaza' ]
avaliacoes.mean(axis=1).plot.bar()
